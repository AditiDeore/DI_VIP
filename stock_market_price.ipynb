# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn import metrics

# %%
df = pd.read_csv('dataset_test.csv')
df.head()
# Out:
#   company  age  market  year  month  day  hour  minute   volume     high  ...  \
# 0    CNDT  0.0  NASDAQ  2021     12   10    15      30   792397     5.41  ...
# 1    CNDT  1.0  NASDAQ  2021     12    9    15      30  1134639     5.46  ...
# 2    CNDT  2.0  NASDAQ  2021     12    8    15      30   939646     5.47  ...
# 3    CNDT  3.0  NASDAQ  2021     12    7    15      30  1301257     5.51  ...
# 4    CNDT  4.0  NASDAQ  2021     12    6    15      30  1090706  5365.00  ...
#
#    AVERAGE_SMA_50_HIGHLOW  EMA_50_HIGHLOW  MACD_50_HIGHLOW  \
# 0                     0.2        230000.0         -30000.0
# 1                     0.2        230000.0         -20000.0
# 2                     0.2        230000.0         -30000.0
# 3                     0.2        230000.0         -30000.0
# 4                     0.2        230000.0         -30000.0
#
#    AVERAGE_SMA_50_VOLUME  EMA_50_VOLUME  MACD_50_VOLUME  \
# 0              1173839.5   1.313408e+09   -2.066295e+09
# 1              1205795.2  -1.090610e+09   -4.850086e+07
# 2              1201770.2  -8.206629e+08   -1.021058e+09
# 3              1197837.6  -4.582356e+08    1.865824e+09
# 4              1189088.3  -6.176610e+08   -1.852724e+09
#
#    DAYS_UNTIL_END_OF_MONTH  DAYS_UNTIL_END_OF_TRIMESTER  DINAMIC3  TARGET
# 0                     18.0                         18.0    0.5781     NaN
# 1                     18.0                         18.0    0.8089     NaN
# 2                     18.0                         18.0    0.6823     NaN
# 3                     18.0                         18.0    0.9432     NaN
# 4                     18.0                         18.0    0.7731     NaN
#
# [5 rows x 77 columns]

# %%
df.shape
# Out:
# (98192, 77)

# %%
df.describe()
# Out:
#                 age          year         month           day          hour  \
# count  98192.000000  98192.000000  98192.000000  98192.000000  98192.000000
# mean     125.426511   2020.944537      6.585710     15.646886     14.940525
# std       72.733097      0.228882      3.423395      8.728922      0.236513
# min        0.000000   2020.000000      1.000000      1.000000     14.000000
# 25%       62.000000   2021.000000      4.000000      8.000000     15.000000
# 50%      125.000000   2021.000000      7.000000     16.000000     15.000000
# 75%      188.000000   2021.000000     10.000000     23.000000     15.000000
# max      251.000000   2021.000000     12.000000     31.000000     15.000000
#
#         minute        volume          high           low          close  ...  \
# count  98192.0  9.819200e+04  9.819200e+04  9.819200e+04   98192.000000  ...
# mean      30.0  1.253721e+06  3.629737e+03  3.248932e+03     243.539935  ...
# std        0.0  6.292186e+06  4.186605e+04  3.582267e+04    3186.373805  ...
# min       30.0  0.000000e+00  3.648000e-01  3.129000e-01       0.312900  ...
# 25%       30.0  5.377325e+04  7.330000e+00  6.860000e+00       6.640000  ...
# 50%       30.0  2.227805e+05  1.964000e+01  1.865000e+01      17.520000  ...
# 75%       30.0  7.806512e+05  5.140000e+01  4.834257e+01      42.510000  ...
# max       30.0  7.397306e+08  2.925075e+06  2.944895e+06  332989.000000  ...
#
#        AVERAGE_SMA_50_HIGHLOW  EMA_50_HIGHLOW  MACD_50_HIGHLOW  \
# count            78692.000000    7.869200e+04     7.869200e+04
# mean                 1.536986    1.536381e+06     1.916548e+04
# std                  3.574251    3.574079e+06     4.498380e+05
# min                  0.000000    1.000000e+04    -9.260000e+06
# 25%                  0.300000    2.900000e+05    -4.000000e+04
# 50%                  0.700000    6.700000e+05     1.000000e+04
# 75%                  1.500000    1.500000e+06     7.000000e+04
# max                 56.700000    5.668000e+07     9.800000e+06
#
#        AVERAGE_SMA_50_VOLUME  EMA_50_VOLUME  MACD_50_VOLUME  \
# count           7.869200e+04   7.869200e+04    7.869200e+04
# mean            1.227726e+06  -1.424871e+06    2.100079e+06
# std             3.219572e+06   1.240939e+09    1.231001e+09
# min             7.211000e+02  -2.147447e+09   -2.147473e+09
# 25%             7.248385e+04  -1.081544e+09   -1.050150e+09
# 50%             2.903338e+05  -7.320208e+06    3.106888e+06
# 75%             9.326882e+05   1.073657e+09    1.056888e+09
# max             5.207516e+07   2.147337e+09    2.147451e+09
#
#        DAYS_UNTIL_END_OF_MONTH  DAYS_UNTIL_END_OF_TRIMESTER      DINAMIC3  \
# count                  97022.0                      97022.0  97022.000000
# mean                      18.0                         18.0     75.072267
# std                        0.0                          0.0    575.470165
# min                       18.0                         18.0      0.000000
# 25%                       18.0                         18.0      0.568425
# 50%                       18.0                         18.0      0.957200
# 75%                       18.0                         18.0      1.109375
# max                       18.0                         18.0  70604.000000
#
#              TARGET
# count  82202.000000
# mean       0.056665
# std        0.231203
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 75 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98192 entries, 0 to 98191
# Data columns (total 77 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   company                      98192 non-null  object
#  1   age                          98192 non-null  float64
#  2   market                       98192 non-null  object
#  3   year                         98192 non-null  int64
#  4   month                        98192 non-null  int64
#  5   day                          98192 non-null  int64
#  6   hour                         98192 non-null  int64
#  7   minute                       98192 non-null  int64
#  8   volume                       98192 non-null  int64
#  9   high                         98192 non-null  float64
#  10  low                          98192 non-null  float64
#  11  close                        98192 non-null  float64
#  12  open                         98192 non-null  float64
#  13  AVERAGE_SMA_3_CLOSE          97022 non-null  float64
#  14  EMA_3_CLOSE                  97022 non-null  float64
#  15  MACD_3_CLOSE                 97022 non-null  float64
#  16  AVERAGE_SMA_3_OPENHIGH       97022 non-null  float64
#  17  EMA_3_OPENHIGH               97022 non-null  float64
#  18  MACD_3_OPENHIGH              97022 non-null  float64
#  19  AVERAGE_SMA_3_HIGHLOW        97022 non-null  float64
#  20  EMA_3_HIGHLOW                97022 non-null  float64
#  21  MACD_3_HIGHLOW               97022 non-null  float64
#  22  AVERAGE_SMA_3_VOLUME         97022 non-null  float64
#  23  EMA_3_VOLUME                 97022 non-null  float64
#  24  MACD_3_VOLUME                97022 non-null  float64
#  25  AVERAGE_SMA_4_CLOSE          96632 non-null  float64
#  26  EMA_4_CLOSE                  96632 non-null  float64
#  27  MACD_4_CLOSE                 96632 non-null  float64
#  28  AVERAGE_SMA_4_OPENHIGH       96632 non-null  float64
#  29  EMA_4_OPENHIGH               96632 non-null  float64
#  30  MACD_4_OPENHIGH              96632 non-null  float64
#  31  AVERAGE_SMA_4_HIGHLOW        96632 non-null  float64
#  32  EMA_4_HIGHLOW                96632 non-null  float64
#  33  MACD_4_HIGHLOW               96632 non-null  float64
#  34  AVERAGE_SMA_4_VOLUME         96632 non-null  float64
#  35  EMA_4_VOLUME                 96632 non-null  float64
#  36  MACD_4_VOLUME                96632 non-null  float64
#  37  AVERAGE_SMA_7_CLOSE          95462 non-null  float64
#  38  EMA_7_CLOSE                  95462 non-null  float64
#  39  MACD_7_CLOSE                 95462 non-null  float64
#  40  AVERAGE_SMA_7_OPENHIGH       95462 non-null  float64
#  41  EMA_7_OPENHIGH               95462 non-null  float64
#  42  MACD_7_OPENHIGH              95462 non-null  float64
#  43  AVERAGE_SMA_7_HIGHLOW        95462 non-null  float64
#  44  EMA_7_HIGHLOW                95462 non-null  float64
#  45  MACD_7_HIGHLOW               95462 non-null  float64
#  46  AVERAGE_SMA_7_VOLUME         95462 non-null  float64
#  47  EMA_7_VOLUME                 95462 non-null  float64
#  48  MACD_7_VOLUME                95462 non-null  float64
#  49  AVERAGE_SMA_20_CLOSE         90392 non-null  float64
#  50  EMA_20_CLOSE                 90392 non-null  float64
#  51  MACD_20_CLOSE                90392 non-null  float64
#  52  AVERAGE_SMA_20_OPENHIGH      90392 non-null  float64
#  53  EMA_20_OPENHIGH              90392 non-null  float64
#  54  MACD_20_OPENHIGH             90392 non-null  float64
#  55  AVERAGE_SMA_20_HIGHLOW       90392 non-null  float64
#  56  EMA_20_HIGHLOW               90392 non-null  float64
#  57  MACD_20_HIGHLOW              90392 non-null  float64
#  58  AVERAGE_SMA_20_VOLUME        90392 non-null  float64
#  59  EMA_20_VOLUME                90392 non-null  float64
#  60  MACD_20_VOLUME               90392 non-null  float64
#  61  AVERAGE_SMA_50_CLOSE         78692 non-null  float64
#  62  EMA_50_CLOSE                 78692 non-null  float64
#  63  MACD_50_CLOSE                78692 non-null  float64
#  64  AVERAGE_SMA_50_OPENHIGH      78692 non-null  float64
#  65  EMA_50_OPENHIGH              78692 non-null  float64
#  66  MACD_50_OPENHIGH             78692 non-null  float64
#  67  AVERAGE_SMA_50_HIGHLOW       78692 non-null  float64
#  68  EMA_50_HIGHLOW               78692 non-null  float64
#  69  MACD_50_HIGHLOW              78692 non-null  float64
#  70  AVERAGE_SMA_50_VOLUME        78692 non-null  float64
#  71  EMA_50_VOLUME                78692 non-null  float64
#  72  MACD_50_VOLUME               78692 non-null  float64
#  73  DAYS_UNTIL_END_OF_MONTH      97022 non-null  float64
#  74  DAYS_UNTIL_END_OF_TRIMESTER  97022 non-null  float64
#  75  DINAMIC3                     97022 non-null  float64
#  76  TARGET                       82202 non-null  float64
# dtypes: float64(69), int64(6), object(2)
# memory usage: 57.7+ MB

# %%
print(df.columns)
# Out:
# Index(['company', 'age', 'market', 'year', 'month', 'day', 'hour', 'minute',
#        'volume', 'high', 'low', 'close', 'open', 'AVERAGE_SMA_3_CLOSE',
#        'EMA_3_CLOSE', 'MACD_3_CLOSE', 'AVERAGE_SMA_3_OPENHIGH',
#        'EMA_3_OPENHIGH', 'MACD_3_OPENHIGH', 'AVERAGE_SMA_3_HIGHLOW',
#        'EMA_3_HIGHLOW', 'MACD_3_HIGHLOW', 'AVERAGE_SMA_3_VOLUME',
#        'EMA_3_VOLUME', 'MACD_3_VOLUME', 'AVERAGE_SMA_4_CLOSE', 'EMA_4_CLOSE',
#        'MACD_4_CLOSE', 'AVERAGE_SMA_4_OPENHIGH', 'EMA_4_OPENHIGH',
#        'MACD_4_OPENHIGH', 'AVERAGE_SMA_4_HIGHLOW', 'EMA_4_HIGHLOW',
#        'MACD_4_HIGHLOW', 'AVERAGE_SMA_4_VOLUME', 'EMA_4_VOLUME',
#        'MACD_4_VOLUME', 'AVERAGE_SMA_7_CLOSE', 'EMA_7_CLOSE', 'MACD_7_CLOSE',
#        'AVERAGE_SMA_7_OPENHIGH', 'EMA_7_OPENHIGH', 'MACD_7_OPENHIGH',
#        'AVERAGE_SMA_7_HIGHLOW', 'EMA_7_HIGHLOW', 'MACD_7_HIGHLOW',
#        'AVERAGE_SMA_7_VOLUME', 'EMA_7_VOLUME', 'MACD_7_VOLUME',
#        'AVERAGE_SMA_20_CLOSE', 'EMA_20_CLOSE', 'MACD_20_CLOSE',
#        'AVERAGE_SMA_20_OPENHIGH', 'EMA_20_OPENHIGH', 'MACD_20_OPENHIGH',
#        'AVERAGE_SMA_20_HIGHLOW', 'EMA_20_HIGHLOW', 'MACD_20_HIGHLOW',
#        'AVERAGE_SMA_20_VOLUME', 'EMA_20_VOLUME', 'MACD_20_VOLUME',
#        'AVERAGE_SMA_50_CLOSE', 'EMA_50_CLOSE', 'MACD_50_CLOSE',
#        'AVERAGE_SMA_50_OPENHIGH', 'EMA_50_OPENHIGH', 'MACD_50_OPENHIGH',
#        'AVERAGE_SMA_50_HIGHLOW', 'EMA_50_HIGHLOW', 'MACD_50_HIGHLOW',
#        'AVERAGE_SMA_50_VOLUME', 'EMA_50_VOLUME', 'MACD_50_VOLUME',
#        'DAYS_UNTIL_END_OF_MONTH', 'DAYS_UNTIL_END_OF_TRIMESTER', 'DINAMIC3',
#        'TARGET'],
#       dtype='object')

# %%
plt.figure(figsize=(15,5))
plt.plot(df['volume'])
plt.title('Stock Market Price Prediction', fontsize=15)
plt.ylabel('Price in dollars.')
plt.show()

# %%
df = df.drop(['volume'], axis=1)
df.isnull().sum()
# Out:
# company                            0
# age                                0
# market                             0
# year                               0
# month                              0
#                                ...
# MACD_50_VOLUME                 19500
# DAYS_UNTIL_END_OF_MONTH         1170
# DAYS_UNTIL_END_OF_TRIMESTER     1170
# DINAMIC3                        1170
# TARGET                         15990
# Length: 76, dtype: int64

# %%
features = ['year', 'month', 'day', 'hour', 'minute']

plt.subplots(figsize=(20,10))

for i, col in enumerate(features):
    plt.subplot(2,3,i+1)
    sb.distplot(df[col])
plt.show()

# %%
plt.subplots(figsize=(20,10))
for i, col in enumerate(features):
    plt.subplot(2,3,i+1)
    sb.boxplot(df[col])
plt.show()

# %%
df['year'] = df['year'].astype(str)
splitted = df['year'].str.split('/', expand=True)
if len(splitted.columns) > 1:
    df['month'] = splitted[1].astype(int)
else:
    df['month'] = None
df['day'] = splitted[0].astype(int)

# %%
df['is_quarter_end'] = np.where(df['month']%3==0,1,0)
df.head()
# Out:
#   company  age  market  year month   day  hour  minute     high      low  ...  \
# 0    CNDT  0.0  NASDAQ  2021  None  2021    15      30     5.41  5305.00  ...
# 1    CNDT  1.0  NASDAQ  2021  None  2021    15      30     5.46     5.32  ...
# 2    CNDT  2.0  NASDAQ  2021  None  2021    15      30     5.47     5.32  ...
# 3    CNDT  3.0  NASDAQ  2021  None  2021    15      30     5.51     5.30  ...
# 4    CNDT  4.0  NASDAQ  2021  None  2021    15      30  5365.00     5.23  ...
#
#    EMA_50_HIGHLOW  MACD_50_HIGHLOW  AVERAGE_SMA_50_VOLUME  EMA_50_VOLUME  \
# 0        230000.0         -30000.0              1173839.5   1.313408e+09
# 1        230000.0         -20000.0              1205795.2  -1.090610e+09
# 2        230000.0         -30000.0              1201770.2  -8.206629e+08
# 3        230000.0         -30000.0              1197837.6  -4.582356e+08
# 4        230000.0         -30000.0              1189088.3  -6.176610e+08
#
#    MACD_50_VOLUME  DAYS_UNTIL_END_OF_MONTH  DAYS_UNTIL_END_OF_TRIMESTER  \
# 0   -2.066295e+09                     18.0                         18.0
# 1   -4.850086e+07                     18.0                         18.0
# 2   -1.021058e+09                     18.0                         18.0
# 3    1.865824e+09                     18.0                         18.0
# 4   -1.852724e+09                     18.0                         18.0
#
#    DINAMIC3  TARGET  is_quarter_end
# 0    0.5781     NaN               0
# 1    0.8089     NaN               0
# 2    0.6823     NaN               0
# 3    0.9432     NaN               0
# 4    0.7731     NaN               0
#
# [5 rows x 77 columns]
